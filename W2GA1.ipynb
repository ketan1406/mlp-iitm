# %% [markdown]
# # WEEK2 GA1

# %% [markdown]
# ## Q1
#
# Find shape of the Wisconsin breast cancer data's feature matrix (accessed from sklearn.datasets)

# %%
from sklearn.datasets import load_breast_cancer

# Load the dataset
data = load_breast_cancer()

# Get the feature matrix (X) shape
print("Feature matrix shape:", data.data.shape)
# Out:
# Feature matrix shape: (569, 30)

# %% [markdown]
# ## Q2
#
# How many benign ( B ) tumour cases are present in the Wisconsin breast cancer dataset ?

# %%
# Count benign cases (encoded as 1 in the target array)
benign_count = sum(data.target == 1)

print("Number of benign (B) tumor cases:", benign_count)
# Out:
# Number of benign (B) tumor cases: 357

# %% [markdown]
# ## Q3
#
# How many malignant ( M ) tumour cases are present in the Wisconsin breast cancer dataset.

# %%
# Count benign cases (encoded as 1 in the target array)
malignant_count = sum(data.target == 0)

print("Number of malignant (M) tumor cases:", malignant_count)
# Out:
# Number of malignant (M) tumor cases: 212

# %% [markdown]
# Q4
#
#  Use the following code for importing California Housing dataset from sklearn. Also, name the dataset as housing_data and print description of the dataset.
#
#  ![image.png](data:image/png;base64,...)

# %%
from sklearn.datasets import fetch_california_housing
housing_data = fetch_california_housing()
print(housing_data.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 20640
#
# :Number of Attributes: 8 numeric, predictive attributes and the target
#
# :Attribute Information:
#     - MedInc        median income in block group
#     - HouseAge      median house age in block group
#     - AveRooms      average number of rooms per household
#     - AveBedrms     average number of bedrooms per household
#     - Population    block group population
#     - AveOccup      average number of household members
#     - Latitude      block group latitude
#     - Longitude     block group longitude
#
# :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# expressed in hundreds of thousands of dollars ($100,000).
#
# ...

# %% [markdown]
# ## Q5
#
# Find out the labels of the first five rows(samples) in california housing dataset. Note, the labels are real-valued.

# %%
# Get labels (target values) of the first five samples
print("First five labels:", housing_data.target[:5].tolist())
# Out:
# First five labels: [4.526, 3.585, 3.521, 3.413, 3.422]
